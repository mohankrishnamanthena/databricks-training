# %%
emp_df = spark.read.csv("file:/Workspace/Users/iluqmanshaik255@gmail.com/empData.csv",
header=True ,
inferSchema = True )
display(emp_df)

# %%
big_sales_df = spark.read.csv("file:/Workspace/Users/iluqmanshaik255@gmail.com/Big Sales.csv" ,
header =True,
inferSchema= True
)
display(big_sales_df)
